# %%
import requests
import pandas as pd
import numpy as np

# %%
def get_request(url, endpoint):
    response = requests.get(url+endpoint)
    if response.status_code == 200:
        return response.json()['features']
    else:
        return f"Error + {response.status_code}"

# %%
api_url = "https://api.weather.gc.ca/collections/climate-hourly/items"
province_code = "ON"
year = 2020
limit = 300000  # Max number of records the API will return per request
offset = 0  # Start at the beginning of the dataset
all_data = []

# %%
while True:
    params = {
        "lang": "en",
        "limit": limit,
        "offset": offset,
        "PROVINCE_CODE": province_code,
        "UTC_YEAR": year
    }
    
    # Make the API request
    response = requests.get(api_url, params=params)
    
    if response.status_code == 200:
        batch_data = response.json()  # Assumes the API returns JSON formatted data
        number_of_records = len(batch_data)
        
        # Add new data to all_data list (you could also be storing batches to a file or database)
        all_data.extend(batch_data)

        # If the number of records is less than the limit we requested,
        # we've received the last page of data
        if number_of_records < limit:
            break

        # Otherwise, increment the offset to get the next batch of data
        offset += number_of_records

    else:
        print(f"Failed to retrieve data: {response.status_code}")
        # Handle the error appropriately - retry logic, logging, etc.
        break

# %%
df_yearly = pd.DataFrame(response.json()['features'])
df_yearly.head()
# Out:
#                       id     type  \
# 0  6158875.2019.12.31.19  Feature
# 1  6158875.2019.12.31.20  Feature
# 2  6158875.2019.12.31.21  Feature
# 3  6158875.2019.12.31.22  Feature
# 4  6158875.2019.12.31.23  Feature
#
#                                             geometry  \
# 0  {'coordinates': [-77.52805555555555, 44.118888...
# 1  {'coordinates': [-77.52805555555555, 44.118888...
# 2  {'coordinates': [-77.52805555555555, 44.118888...
# 3  {'coordinates': [-77.52805555555555, 44.118888...
# 4  {'coordinates': [-77.52805555555555, 44.118888...
#
#                                           properties
# 0  {'TEMP_FLAG': None, 'HUMIDEX_FLAG': None, 'LOC...
# 1  {'TEMP_FLAG': None, 'HUMIDEX_FLAG': None, 'LOC...
# 2  {'TEMP_FLAG': None, 'HUMIDEX_FLAG': None, 'LOC...
# 3  {'TEMP_FLAG': None, 'HUMIDEX_FLAG': None, 'LOC...
# 4  {'TEMP_FLAG': None, 'HUMIDEX_FLAG': None, 'LOC...

# %%
import json
def ensure_dict(obj):
    if isinstance(obj, str):
        try:
            return json.loads(obj.replace("'", "\""))
        except json.JSONDecodeError:
            return {}
    return obj

# %%
df_yearly['geometry'] = df_yearly['geometry'].apply(ensure_dict)
df_yearly['properties'] = df_yearly['properties'].apply(ensure_dict)
df_yearly.head()
# Out:
#                       id     type  \
# 0  6158875.2019.12.31.19  Feature
# 1  6158875.2019.12.31.20  Feature
# 2  6158875.2019.12.31.21  Feature
# 3  6158875.2019.12.31.22  Feature
# 4  6158875.2019.12.31.23  Feature
#
#                                             geometry  \
# 0  {'coordinates': [-77.52805555555555, 44.118888...
# 1  {'coordinates': [-77.52805555555555, 44.118888...
# 2  {'coordinates': [-77.52805555555555, 44.118888...
# 3  {'coordinates': [-77.52805555555555, 44.118888...
# 4  {'coordinates': [-77.52805555555555, 44.118888...
#
#                                           properties
# 0  {'TEMP_FLAG': None, 'HUMIDEX_FLAG': None, 'LOC...
# 1  {'TEMP_FLAG': None, 'HUMIDEX_FLAG': None, 'LOC...
# 2  {'TEMP_FLAG': None, 'HUMIDEX_FLAG': None, 'LOC...
# 3  {'TEMP_FLAG': None, 'HUMIDEX_FLAG': None, 'LOC...
# 4  {'TEMP_FLAG': None, 'HUMIDEX_FLAG': None, 'LOC...

# %% [markdown]
# # Pd.series
#
# - A Pandas Series is like a column in a table. It is a one-dimensional array holding data of any type.

# %%
df_yearly[['longitude', 'latitude']] = df_yearly['geometry'].apply(
    lambda x: x.get('coordinates', [None, None])).apply(pd.Series)

properties_df = df_yearly['properties'].apply(pd.Series)

# %%
df_yearly = pd.concat([df_yearly.drop(['geometry', 'properties'], axis=1), properties_df], axis=1)

# %%
df_yearly.head()
# Out:
#                       id     type  longitude   latitude TEMP_FLAG  \
# 0  6158875.2019.12.31.19  Feature -77.528056  44.118889      None
# 1  6158875.2019.12.31.20  Feature -77.528056  44.118889      None
# 2  6158875.2019.12.31.21  Feature -77.528056  44.118889      None
# 3  6158875.2019.12.31.22  Feature -77.528056  44.118889      None
# 4  6158875.2019.12.31.23  Feature -77.528056  44.118889      None
#
#   HUMIDEX_FLAG  LOCAL_MONTH PRECIP_AMOUNT_FLAG WINDCHILL_FLAG WIND_SPEED_FLAG  \
# 0         None           12               None           None            None
# 1         None           12               None           None            None
# 2         None           12               None           None            None
# 3         None           12               None           None            None
# 4         None           12               None           None            None
#
#    ... DEW_POINT_TEMP_FLAG UTC_YEAR UTC_MONTH  STATION_PRESSURE  \
# 0  ...                None     2020         1             98.91
# 1  ...                None     2020         1             98.90
# 2  ...                None     2020         1             98.89
# 3  ...                None     2020         1             98.91
# 4  ...                None     2020         1             98.93
#
#    WIND_DIRECTION  STATION_NAME PRECIP_AMOUNT  VISIBILITY_FLAG  \
# 0            23.0     TRENTON A           NaN             None
# 1            24.0     TRENTON A           NaN             None
# 2            25.0     TRENTON A           NaN             None
# 3            25.0     TRENTON A           NaN             None
# 4            25.0     TRENTON A           NaN             None
#
#               UTC_DATE  WEATHER_FRE_DESC
# 0  2020-01-01T00:00:00           Nuageux
# 1  2020-01-01T01:00:00  Averses de neige
# 2  2020-01-01T02:00:00           Nuageux
# 3  2020-01-01T03:00:00           Nuageux
# 4  2020-01-01T04:00:00           Nuageux
#
# [5 rows x 39 columns]

# %%
df_yearly.to_csv(f'./data/weather_data{year}.csv', index=False)
